# %%
import pandas as pd

# %%
[['Building']]

# %%
pd.read_csv('building_area/Rooms.csv')
# Out:
#         Building        Floor  Suite         Room Space   Pct  Area  Stations  \
# 0    Center Hall     Basement    NaN      (CE)B09   NaN  100%    64       NaN
# 1    Center Hall     Basement    NaN      (CE)B10   NaN  100%    60       NaN
# 2    Center Hall     Basement    NaN  (CU)171-B-0   NaN  100%   445       NaN
# 3    Center Hall     Basement    NaN       (M)B01   NaN  100%  1431       NaN
# 4    Center Hall     Basement    NaN       (M)B02   NaN  100%   299       NaN
# 5    Center Hall     Basement    NaN       (M)B03   NaN  100%    56       NaN
# 6    Center Hall     Basement    NaN       (M)B04   NaN  100%   170       NaN
# 7    Center Hall     Basement    NaN       (M)B05   NaN  100%    65       NaN
# 8    Center Hall     Basement    NaN       (M)B06   NaN  100%   105       NaN
# 9    Center Hall     Basement    NaN       (M)B07   NaN  100%   105       NaN
# 10   Center Hall     Basement    NaN       (M)B08   NaN  100%   142       NaN
# ...

# %%
['Building', 'Room', 'Category', 'Area', '']

# %%
room_df = pd.read_csv('building_area/Rooms.csv')

# %%
room_df = room_df[room_df['Category'].str.match('A - Assignable Area')][['Building', 'Room', 'Area', 'Room Use (S)']]

# %%
#Returns 
def extract_buildingData(bd_filepath, building_name, room_use):
    room_df = pd.read_csv('bd_filepath')
    room_df = room_df[room_df['Category'].str.match('A - Assignable Area')][['Building', 
                                                                             'Room', 
                                                                             'Area', 
                                                                             'Room Use (S)']]
    if building_name != rooms_df[['Building']]:
        print('Error: Building Name of input file does not match desired Building Name')
    room_df = room_df.loc[room_df['Category']]
    rooms = room_df[['Rooms']]
# Out:
#   File "<ipython-input-5-8c78c41e7584>", line 2
#     pd.read_csv('bd_filepath'):
#                                ^
# SyntaxError: invalid syntax
